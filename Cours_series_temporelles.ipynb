# %% [markdown]
# COURS SERIES TEMPORELLES

# %% [markdown]
# **COURS SERIES TEMPORELLES**

# %% [markdown]
# **1. Définition**
#
# **2. Applications**
#
# **3. Analyse d'une serie temporelle**
#
# **4. Décomposition d'une serie temporelle**
#
# **5. Modèles d'analyse des séries temporelles**

# %% [markdown]
# ### 1. définition
# - On appelle série chronologique, ou bien encore chronique ou série temporelle, une suite finie de donnees quantitatives indexée par le temps.
# - L’indice temps peut ˆetre selon les cas, la seconde, la minute, l’heure, le
# - Les series chronologiques répresentent donc l'évolution d'un phénomène aucours du temps telle que:
# ![image.png](attachment:44adc66d-564f-43b2-94ee-9021149c192e.png)
#  - Xt est la résulatante des différentes composantes que sont la tendance, la saisonnalité et le résidu(erreur).

# %% [markdown]
# ### 2. Applications
#
# ![image.png](attachment:eaeea405-e427-4255-83c4-b114ee8c6613.png)
#
# ![image.png](attachment:76981777-d115-4cc5-80c7-3eb9b4320f01.png)

# %% [markdown]
# ### 3. Analyse d'une serie temporelle
# ![image.png](attachment:c2ec4465-d911-438e-b00b-e17a752467c4.png)

# %% [markdown]
# #### 3.1. Tendance
# ![image.png](attachment:76ae054b-480a-4834-a94a-1bda7a2fb022.png)

# %% [markdown]
# ![image.png](attachment:f1a3c3b3-7b8a-4c35-aa7e-d66fb9f93a5c.png)
#
# - Tendance croissante
#
#   ![image.png](attachment:b40c6eb4-eeef-44bc-bfa8-e56089fceb17.png)

# %% [markdown]
# - Tendance décroissante
# ![image.png](attachment:4bf90827-459c-4d0c-a3b1-f5ef1e9f4350.png)

# %% [markdown]
# ![image.png](attachment:bd13c2a2-26cc-41fb-b5a0-bcd996412c85.png)

# %% [markdown]
# #### 3.2. Saisonnalité
# ![image.png](attachment:06dbaddc-ea34-44b9-ae0f-9a3a09565373.png)
# ![image.png](attachment:54545b4a-2da5-4609-8e4e-c721c0343bde.png)
# ![image.png](attachment:69e2cc07-175a-4034-bd13-2ccc288445d7.png)

# %% [markdown]
# #### 3.3. Le résidu
# ![image.png](attachment:11e2a834-cdaa-4385-b428-b59074cf068b.png)

# %% [markdown]
# ### 4. Time series decomposition
# [Time series decomposition](https://www.section.io/engineering-education/time-series-decomposition-in-python/)
# ![image.png](attachment:bf23c61e-7849-43a1-b8f8-639c9591ee76.png)

# %% [markdown]
# #### 4.1 Additive model
# ![image.png](attachment:0d5d978d-f3d6-4ae3-8b2a-6b6a6cd3ee8b.png)
# ![image.png](attachment:afbd6f4e-6c59-4122-9b16-2d1823f65e1c.png) ![image.png](attachment:1ee3985a-ab76-4090-be49-507874b9f20b.png)

# %% [markdown]
# #### 4.2. Multiplicative model
# ![image.png](attachment:afd23577-df6f-4f17-885b-9c502301fa13.png)
# ![image.png](attachment:86836d7d-3796-42cd-83fe-7e38336d65b4.png)

# %% [markdown]
# ### 4. Décomposition d'une serie temporelle

# %% [markdown]
# 1. Tendance   2. Saisonnalité   3. résidus ou bruits

# %% [markdown]
# ![image.png](attachment:d377e493-c464-4b84-98bd-5ff59c784b3d.png)

# %% [markdown]
# ![image.png](attachment:43949f33-0a8a-407e-8b4c-a952ac4b60de.png)

# %% [markdown]
# ### 5. Modèles d'analyse des séries temporelles

# %% [markdown]
# #### 5.1. Autoregressive (AR) Models

# %% [markdown]
# [AR models](https://vitalflux.com/autoregressive-ar-models-with-python-examples/)

# %% [markdown]
# ![image.png](attachment:1650228b-a6be-44ff-b774-2e6d26e35b08.png)
# ![image.png](attachment:b3ae28e0-4129-4d83-b64f-442c4f1e3936.png)
# ![image.png](attachment:9cc7ce0f-bde6-41a8-bc1b-9e15904223b1.png)
# ![image.png](attachment:42f888d5-0a9e-44fa-8584-865f7dcf179d.png)

# %% [markdown]
# #### 5.2. ARIMA model
# [ARIMA models](https://www.machinelearningplus.com/time-series/arima-model-time-series-forecasting-python/)

# %% [markdown]
# ![image.png](attachment:6d93aa53-861b-4d4e-8cf0-99fb54956632.png)
# ![image.png](attachment:2626e8c2-201d-4831-9f97-f9802fb768d2.png)
# ![image.png](attachment:32650a2f-6402-4a40-8fbc-6eea59b16de3.png)
# ![image.png](attachment:f4f36b16-5728-4b81-aa6e-6117b70ae43c.png)
# ![image.png](attachment:90eaae56-c556-4f17-b0eb-35884207de61.png)

# %% [markdown]
# ![image.png](attachment:5aa57775-b1ee-490c-9ab7-8cddc21f2968.png)
# ![image.png](attachment:3038cba5-9343-4667-b08b-229f084d1c6f.png)
# ![image.png](attachment:79bb2ca2-08b1-45da-badf-3b2a38efe135.png)

# %% [markdown]
# ![image.png](attachment:4e323bc6-eda6-43fa-9eec-6ba2fe281a15.png)

# %% [markdown]
# #### How to find p
# ![image.png](attachment:033cc8e0-bc5c-427a-9e4d-d74269e9056e.png)
# ![image.png](attachment:661b5569-ccbe-4ed8-be5a-3873b93971aa.png)

# %% [markdown]
# ####  How to find the order of the MA term (q)
# ![image.png](attachment:5e0a8712-6eba-42a1-a021-ec6f78a16f60.png)
# ##### Notes
# ![image.png](attachment:46574403-7a14-42d3-beff-b9db5756e51c.png)

# %% [markdown]
# [ARIMA and other models](https://www.machinelearningplus.com/time-series/arima-model-time-series-forecasting-python/)
# ![image.png](attachment:bec07d3d-88ed-4688-bd73-84a1cc0c84b8.png)
